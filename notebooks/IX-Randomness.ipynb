# %% [markdown]
# #IX-[Randomness](http://lmgtfy.com/?q=Randomness&l=1)

# %%
from IPython.display import Image

# %%
Image('http://imgs.xkcd.com/comics/random_number.png')

# %%
Image('http://imgs.xkcd.com/comics/ayn_random.png')

# %%
Image('http://www.random.org/analysis/dilbert.jpg')

# %%
import numpy as np

# %% [markdown]
# The *random* subpackage is the package responsible for all random functions in the numpy environment

# %%
#help(np.random)

# %% [markdown]
# Let's generate a couple of random paths

# %%
Nt = 1000
Npaths = 10
rv = np.random.randn(10,1000)

# %%
rv.shape
# Out:
# (10, 1000)

# %%
paths = rv.cumsum(1)

# %%
paths.shape
# Out:
# (10, 1000)

# %%
# %matplotlib inline
from matplotlib.pyplot import *
import seaborn as sns
sns.set(style='ticks', palette='Set2')

# %%
plot(paths.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa41da5d9d0>,
#  <matplotlib.lines.Line2D at 0x7fa41da5d090>,
#  <matplotlib.lines.Line2D at 0x7fa41da48850>,
#  <matplotlib.lines.Line2D at 0x7fa41da48b50>,
#  <matplotlib.lines.Line2D at 0x7fa41da3c9d0>,
#  <matplotlib.lines.Line2D at 0x7fa41da3cb90>,
#  <matplotlib.lines.Line2D at 0x7fa41da48e10>,
#  <matplotlib.lines.Line2D at 0x7fa41da3cf10>,
#  <matplotlib.lines.Line2D at 0x7fa41d9d0110>,
#  <matplotlib.lines.Line2D at 0x7fa41d9d02d0>]
# /home/jpsilva/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1279: UserWarning: findfont: Font family [u'Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Even though Numpy has a random subpackage, it is in SciPy that we find a more complete package. To note that since python 3.4 a statistical package is included in the default python bundle

# %%
from scipy import stats

# %% [markdown]
# We can easily get a list of available distributions (continuous and discrete) by using *dir* or by checking on the online [documentation](http://docs.scipy.org/doc/scipy/reference/stats.html#continuous-distributions)

# %%
list_distributions = dir(stats)
len(list_distributions)
# Out:
# 243

# %% [markdown]
# Let's choose a Pareto distribution with parameter $\alpha=3$ $$ pdf_{pareto}(x) = \frac{\alpha}{x^{\alpha+1}} $$

# %%
alpha = 3
X = stats.pareto(alpha)

# %% [markdown]
# We can sample...

# %%
n = 100
plot(X.rvs(n),'.')

# %% [markdown]
# ...have a look at the probability density function...

# %%
x = np.linspace(X.ppf(0.01), X.ppf(0.99), 100)
plot(x, X.pdf(x),label='Pareto pdf')
legend()
xlabel('$x$')

# %% [markdown]
# ...have a look at the cumulative density function...

# %%
plot(x, X.cdf(x),label='Pareto cdf')
legend()
xlabel('$x$')

# %% [markdown]
# ...compare the histogram of the previously generated sample with the pdf...

# %%
fig, ax = subplots()
ax.hist(X.rvs(10000),normed=True,bins=100)
ax.plot(x,X.pdf(x))

# %% [markdown]
# (let's just see the influence of the number of bins in the non-parametric estimation)

# %%
# %matplotlib
from matplotlib.widgets import Slider

samples = X.rvs(10000)

ax = axes([0.1,0.25,0.8,0.6])
ax.hist(samples,normed=True)
ax.plot(x,X.pdf(x))
sl = Slider(axes([0.1,0.1,0.8,0.1]),'Bins',1,200,valinit=10,valfmt='%d')

def update(data):
    data = int(data)
    ax.cla()
    ax.hist(samples,normed=True,bins=data)
    ax.plot(x,X.pdf(x))
    ax.draw()

sl.on_changed(update)
# Out:
# Using matplotlib backend: Qt4Agg
# 0

# %%
X.stats(moments='mv')
# Out:
# (array(1.5), array(0.75))

# %% [markdown]
# We also have different [statistical tests](http://docs.scipy.org/doc/scipy/reference/stats.html#statistical-functions) available:

# %%
from IPython.display import HTML
HTML('http://docs.scipy.org/doc/scipy/reference/stats.html#statistical-functions')
# Out:
# <!DOCTYPE html>
#
# <html>
#   <head>
#     <meta charset="utf-8">
#
#     <title>Statistical functions (scipy.stats) &mdash; SciPy v0.14.0 Reference Guide</title>
#
#     <link rel="stylesheet" type="text/css" href="_static/css/spc-bootstrap.css">
#     <link rel="stylesheet" type="text/css" href="_static/css/spc-extend.css">
#     <link rel="stylesheet" href="_static/scipy.css" type="text/css" >
#     <link rel="stylesheet" href="_static/pygments.css" type="text/css" >
#
#     <script type="text/javascript">
#       var DOCUMENTATION_OPTIONS = {
#         URL_ROOT:    './',
#         VERSION:     '0.14.0',
#         COLLAPSE_INDEX: false,
#         FILE_SUFFIX: '.html',
#         HAS_SOURCE:  false
#       };
#     </script>
#     <script type="text/javascript" src="_static/jquery.js"></script>
#     <script type="text/javascript" src="_static/underscore.js"></script>
#     <script type="text/javascript" src="_static/doctools.js"></script>
#     <script type="text/javascript" src="_static/js/copybutton.js"></script>
#     <link rel="top" title="SciPy v0.14.0 Reference Guide" href="index.html" >
#     <link rel="next" title="scipy.stats.rv_continuous" href="generated/scipy.stats.rv_continuous.html" >
#     <link rel="prev" title="scipy.special.xlog1py" href="generated/scipy.special.xlog1py.html" >
#   </head>
#   <body>
#
# <div class="container">
#   <div class="top-scipy-org-logo-header">
#     <a href="index.html">
#       <img style="border: 0;" alt="SciPy" src="_static/img/scipy_org_logo.gif"></a>
#     </div>
#   </div>
# </div>
#
#
#     <div class="container">
#       <div class="main">
#
# 	<div class="row-fluid">
# 	  <div class="span12">
# 	    <div class="spc-navbar">
#
#     <ul class="nav nav-pills pull-left">
#         <li class="active"><a href="http://scipy.org/">Scipy.org</a></li>
#         <li class="active"><a href="http://docs.scipy.org/">Docs</a></li>
#
#         <li class="active"><a href="index.html">SciPy v0.14.0 Reference Guide</a></li>
#
#     </ul>
#
#
#     <ul class="nav nav-pills pull-right">
#       <li class="active">
#         <a href="genindex.html" title="General Index"
#            accesskey="I">index</a>
#       </li>
#       <li class="active">
#         <a href="py-modindex.html" title="Python Module Index"
#            >modules</a>
#       </li>
#       <li class="active">
#         <a href="generated/scipy.stats.rv_continuous.html" title="scipy.stats.rv_continuous"
#            accesskey="N">next</a>
#       </li>
#       <li class="active">
#         <a href="generated/scipy.special.xlog1py.html" title="scipy.special.xlog1py"
#            accesskey="P">previous</a>
#       </li>
#     </ul>
#
# 	    </div>
# 	  </div>
# 	</div>
#
#
# 	<div class="row-fluid">
#           <div class="span9">
#
#         <div class="bodywrapper">
#           <div class="body" id="spc-section-body">
#
#   <span class="target" id="module-scipy.stats"></span><div class="section" id="module-scipy.stats">
# <span id="statistical-functions-scipy-stats"></span><h1>Statistical functions (<a class="reference internal" href="#module-scipy.stats" title="scipy.stats"><tt class="xref py py-mod docutils literal"><span class="pre">scipy.stats</span></tt></a>)<a class="headerlink" href="#module-scipy.stats" title="Permalink to this headline">¶</a></h1>
# <p>This module contains a large number of probability distributions as
# well as a growing library of statistical functions.</p>
# <p>Each included distribution is an instance of the class rv_continous:
# For each given name the following methods are available:</p>
# <table border="1" class="longtable docutils">
# <colgroup>
# <col width="10%" />
# <col width="90%" />
# </colgroup>
# <tbody valign="top">
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.html#scipy.stats.rv_continuous" title="scipy.stats.rv_continuous"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous</span></tt></a>([momtype,&nbsp;a,&nbsp;b,&nbsp;xtol,&nbsp;...])</td>
# <td>A generic continuous random variable class meant for subclassing.</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.pdf.html#scipy.stats.rv_continuous.pdf" title="scipy.stats.rv_continuous.pdf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.pdf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Probability density function at x of the given RV.</td>
# </tr>
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.logpdf.html#scipy.stats.rv_continuous.logpdf" title="scipy.stats.rv_continuous.logpdf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.logpdf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Log of the probability density function at x of the given RV.</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.cdf.html#scipy.stats.rv_continuous.cdf" title="scipy.stats.rv_continuous.cdf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.cdf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Cumulative distribution function of the given RV.</td>
# </tr>
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.logcdf.html#scipy.stats.rv_continuous.logcdf" title="scipy.stats.rv_continuous.logcdf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.logcdf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Log of the cumulative distribution function at x of the given RV.</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.sf.html#scipy.stats.rv_continuous.sf" title="scipy.stats.rv_continuous.sf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.sf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Survival function (1-cdf) at x of the given RV.</td>
# </tr>
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.logsf.html#scipy.stats.rv_continuous.logsf" title="scipy.stats.rv_continuous.logsf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.logsf</span></tt></a>(x,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Log of the survival function of the given RV.</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.ppf.html#scipy.stats.rv_continuous.ppf" title="scipy.stats.rv_continuous.ppf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.ppf</span></tt></a>(q,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Percent point function (inverse of cdf) at q of the given RV.</td>
# </tr>
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.isf.html#scipy.stats.rv_continuous.isf" title="scipy.stats.rv_continuous.isf"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.isf</span></tt></a>(q,&nbsp;*args,&nbsp;**kwds)</td>
# <td>Inverse survival function at q of the given RV.</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.moment.html#scipy.stats.rv_continuous.moment" title="scipy.stats.rv_continuous.moment"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.moment</span></tt></a>(n,&nbsp;*args,&nbsp;**kwds)</td>
# <td>n&#8217;th order non-central moment of distribution.</td>
# </tr>
# <tr class="row-odd"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.stats.html#scipy.stats.rv_continuous.stats" title="scipy.stats.rv_continuous.stats"><tt class="xref py py-obj docutils literal"><span class="pre">rv_continuous.stats</span></tt></a>(*args,&nbsp;**kwds)</td>
# <td>Some statistics of the given RV</td>
# </tr>
# <tr class="row-even"><td><a class="reference internal" href="generated/scipy.stats.rv_continuous.entropy.html#scipy.stats.rv_continuous.entropy" title="scipy.stats.rv_continuous.entropy"><tt class="xref p

# %%
from scipy.stats import kstest, normaltest

# %%
normaltest(rv,axis=1)
# Out:
# (array([ 0.76082573,  0.01126978,  5.63147596,  0.27579045,  3.84819305,
#          6.22908574,  2.02861029,  1.9927238 ,  0.46272103,  2.51223795]),
#  array([ 0.68357912,  0.99438096,  0.05986053,  0.87118997,  0.14600761,
#          0.0443988 ,  0.36265433,  0.36922026,  0.79345336,  0.28475703]))

# %%
kstest(rv,'norm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f62508e716a2> in <module>()
# ----> 1 kstest(rv,'norm')
#
# /home/jpsilva/anaconda/lib/python2.7/site-packages/scipy/stats/stats.pyc in kstest(rvs, cdf, args, N, alternative, mode)
#    3433
#    3434     if alternative in ['two-sided', 'greater']:
# -> 3435         Dplus = (np.arange(1.0, N+1)/N - cdfvals).max()
#    3436         if alternative == 'greater':
#    3437             return Dplus, distributions.ksone.sf(Dplus,N)
#
# ValueError: operands could not be broadcast together with shapes (10,) (10,1000)

# %%
rv.apply(kstest,axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-0e6a60028561> in <module>()
# ----> 1 rv.apply(kstest,axis=1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'apply'

# %%
np.apply_along_axis(lambda x: kstest(x,'norm'),1,rv)
# Out:
# array([[ 0.02258851,  0.68729813],
#        [ 0.01953194,  0.84007941],
#        [ 0.04515036,  0.03287574],
#        [ 0.03303197,  0.22065703],
#        [ 0.01654964,  0.94702323],
#        [ 0.04161483,  0.06088554],
#        [ 0.02988619,  0.32853677],
#        [ 0.02706993,  0.45367407],
#        [ 0.02087375,  0.77622773],
#        [ 0.03456065,  0.17926681]])

# %%
map(lambda x: kstest(x,'norm'),rv)
# Out:
# [(0.022588505965900785, 0.68729812624198638),
#  (0.019531941596613533, 0.84007941493806415),
#  (0.045150356571560357, 0.032875739591434527),
#  (0.033031972610236104, 0.22065703230246303),
#  (0.016549643958866267, 0.94702322814609663),
#  (0.041614828353889965, 0.060885539612935746),
#  (0.02988619100346529, 0.32853677135332848),
#  (0.027069927461537302, 0.45367406917234332),
#  (0.020873746378914815, 0.77622773361532782),
#  (0.034560653818090592, 0.17926681073156825)]

# %%
# %%timeit 
np.apply_along_axis(lambda x: kstest(x,'norm'),1,rv)
# Out:
# 100 loops, best of 3: 6.91 ms per loop

# %%
# %%timeit
map(lambda x: kstest(x,'norm'),rv)
# Out:
# 100 loops, best of 3: 6.74 ms per loop

# %%
np.apply_along_axis??

# %%
t_statistic, p_value = stats.ttest_ind(stats.norm.rvs(size=1000), stats.norm.rvs(size=1000))
print p_value
# Out:
# 0.232430093319

# %%
from os import urandom

# %%
ur = urandom(16)
ur
# Out:
# '\t\x89\xd8(\xe3\xc5\x9d1\xcb\x0f\xb3\xa2@\xc4\x01\x90'

# %%
ur.encode('hex')
# Out:
# '0989d828e3c59d31cb0fb3a240c40190'

# %%
import random

# %%
random.random()
# Out:
# 0.0783924721018322

# %% [markdown]
# What about choosing from some predetermined set?

# %%
from os import urandom

# %%
urandom(2).encode('hex')
# Out:
# '33c5'

# %%
a = urandom(64)
a.encode('base-64')
# Out:
# 'iAWjWiaIFFq9hoQ5CZx5k6+xfo3g6vVMKJbcNthGKtpSU9eMwL7hfzNw+DsMGMl58WlluODS+O7S\nz45aRHp1qw==\n'

# %%
from base64 import b64encode
from os import urandom

random_bytes = urandom(64)
token = b64encode(random_bytes).decode('utf-8')
token
# Out:
# u'GxvtJZnpuwj2bR3ggIts+FjgkdQ5dq+rnbhTMoPfqu3ZmUbRcAQ6SBFzwqfmihUTu6uP0laMRKRBQRxIeUqj+Q=='

# %%
# %load_ext version_information
# %version_information numpy, scipy
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 2.7.8 |Anaconda 2.1.0 (64-bit)| (default, Aug 21 2014, 18:22:21) [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# IPython 2.3.1
# OS posix [linux2]
# numpy 1.9.1
# scipy 0.14.0
#
# Sun Dec 07 14:22:10 2014 CET

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:1000px;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 	font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     h4{
# 	font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 140%;
#         font-size: 130%;
#         width:1000px;
#         margin-right:auto;
#     }
#     .CodeMirror{
# 	font-size: 120%;
# 	font-family: 'Monaco', sans-serif;
#     }
# /*      .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
