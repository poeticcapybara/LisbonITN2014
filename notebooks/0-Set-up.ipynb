# %% [markdown]
# <a id='top'></a>

# %% [markdown]
# #[Python](https://www.python.org/)
#
#
# Lecturer:*José Pedro Silva*<sup>[1](http://www-num.math.uni-wuppertal.de/en/amna/people/jose-pedro-silva.html)</sup> - [silva_at_math.uni-wuppertal.de](mailto:silva_at_math.uni-wuppertal.de)

# %% [markdown]
# ### 0. Installation checkup

# %% [markdown]
# The easiest way to setup a working scientific python environment is through [anaconda](http://continuum.io/downloads) from ContinuumIO. You should be able to download it from the following links directly:
#
# - [Linux 64-bit Python 2.7](http://09c8d0b2229f813c1b93-c95ac804525aac4b6dba79b00b39d1d3.r79.cf1.rackcdn.com/Anaconda-2.1.0-Linux-x86_64.sh) [Installation Instructions](http://docs.continuum.io/anaconda/install.html#linux-install)
# - [Linux 32-bit Python 2.7](http://09c8d0b2229f813c1b93-c95ac804525aac4b6dba79b00b39d1d3.r79.cf1.rackcdn.com/Anaconda-2.1.0-Linux-x86.sh) [Installation Instructions](http://docs.continuum.io/anaconda/install.html#linux-install)
# - [Windows 64-bit Python 2.7](http://09c8d0b2229f813c1b93-c95ac804525aac4b6dba79b00b39d1d3.r79.cf1.rackcdn.com/Anaconda-2.1.0-Windows-x86_64.exe) [Installation Instructions](http://docs.continuum.io/anaconda/install.html#windows-install)
# - [Windows 32-bit Python 2.7](http://09c8d0b2229f813c1b93-c95ac804525aac4b6dba79b00b39d1d3.r79.cf1.rackcdn.com/Anaconda-2.1.0-Windows-x86.exe) [Installation Instructions](http://docs.continuum.io/anaconda/install.html#windows-install)
# - [Mac OS X 64-bit Python 2.7](http://09c8d0b2229f813c1b93-c95ac804525aac4b6dba79b00b39d1d3.r79.cf1.rackcdn.com/Anaconda-2.1.0-MacOSX-x86_64.sh) [Installation Instructions](http://docs.continuum.io/anaconda/install.html#mac-install)
#
# After installing run the following commands (Linux and Mac OS X):
#
#     conda update conda
#     conda update numpy scipy matplotlib pandas ipython-notebook pip
#     pip install seaborn
#     pip install memory_profiler

# %% [markdown]
# Open ipython and install the following extension by running the following command in ipython
#
#     %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py

# %% [markdown]
# ## Python, IPython, IDE...

# %% [markdown]
# There are different possibilities to develop python code:
#
#  - [Text-editor](#texteditor)
#  - [Python Interpreter](#interpreter)
#  - [IPython](#ipython)
#  - [Spyder](#spyder)
#  - [PyCharm](#pycharm)
#  - [Other IDE](#ides)

# %%
from IPython.display import Image, HTML

# %% [markdown]
# <a id='texteditor'></a>

# %% [markdown]
# ##### Text-editor

# %% [markdown]
# Ultimately, only a text-editor and python is needed. That way we write the code in plain text, save with the *.py* extension and run it with python

# %%
Image('../data/gedit.png')

# %%
Image('../data/Terminal.png')

# %% [markdown]
# <a id='interpreter'></a>

# %% [markdown]
# ##### Python Interpreter

# %% [markdown]
# Another possibility is to run python from the command line and run interactively. This option should only be used to test small snippets of code

# %%
Image('../data/python.png')

# %% [markdown]
# <a id='ipython'></a>

# %% [markdown]
# ##### IPython

# %% [markdown]
# [IPython](http://ipython.org/index.html) provides a rich architecture for interactive computing with:
#
#  - Powerful interactive shells (terminal and Qt-based).
#  - A browser-based notebook with support for code, text, mathematical expressions, inline plots and other rich media.
#  - Support for interactive data visualization and use of GUI toolkits.
#  - Flexible, embeddable interpreters to load into your own projects.
#  - Easy to use, high performance tools for parallel computing.
#
# Through IPython's kernel and messaging architecture, the Notebook allows code to be run in a range of different programming languages.  For each notebook document that a user opens, the web application starts a kernel that runs the code for that notebook. Each kernel is capable of running code in a single programming language and there are kernels available in the following languages:
#
#  * [Python](https://github.com/ipython/ipython)
#  * [Julia](https://github.com/JuliaLang/IJulia.jl)
#  * [R](https://github.com/takluyver/IRkernel)
#  * [Ruby](https://github.com/minrk/iruby)
#  * [Haskell](https://github.com/gibiansky/IHaskell)
#  * [Scala](https://github.com/Bridgewater/scala-notebook)
#  * [node.js](https://gist.github.com/Carreau/4279371)
#  * [Go](https://github.com/takluyver/igo)
#
# The default kernel runs Python code. When it is released, IPython 3.0 will provide a simple way for users to pick which of these kernels is used for a given notebook.
#
# The next generation of IPython is called [Jupyter](http://jupyter.org/) and it will be a common platform for different languages

# %%
HTML('<iframe src=http://ipython.org/notebook.html width=900 height=768></iframe>')
# Out:
# <iframe src=http://ipython.org/notebook.html width=900 height=768></iframe>

# %% [markdown]
# <a id='spyder'></a>

# %% [markdown]
# ##### Spyder

# %% [markdown]
# [Spyder](https://code.google.com/p/spyderlib/) is a MATLAB-like IDE for scientific computing with python. It should ease the transition to python for MATLAB Users

# %%
Image('../data/spyder.png')

# %% [markdown]
# <a id='pycharm'></a>

# %% [markdown]
# ##### PyCharm

# %% [markdown]
# [PyCharm](https://www.jetbrains.com/pycharm/) (Community Edition) is a freely available IDE from JetBrains. It is written in Java and can integrate with different tools (cvs, web frameworks, pypy, etc...). Its integrated debugger becomes handy for bigger projects. [download link](https://www.jetbrains.com/pycharm/download/)

# %%
Image('../data/pycharm.png')

# %% [markdown]
# <a id='ides'></a>

# %% [markdown]
# ##### Other IDEs

# %% [markdown]
# There are different IDEs tailored for python, apart from the usual vim, emacs, Xcode etc. For a non-exhaustive list, see [Python IDEs](https://wiki.python.org/moin/IntegratedDevelopmentEnvironments) and [Python Editors](https://wiki.python.org/moin/PythonEditors)

# %%
# %load_ext version_information

# %%
# %version_information numpy,scipy,matplotlib,pandas,seaborn
# Out:
# Software versions
# Python 2.7.8 |Anaconda 2.1.0 (64-bit)| (default, Aug 21 2014, 18:22:21) [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# IPython 2.3.0
# OS posix [linux2]
# numpy 1.9.1
# scipy 0.14.0
# matplotlib 1.4.2
# pandas 0.15.0
# seaborn 0.3.1
#
# Thu Dec 04 14:45:40 2014 CET

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 	font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     h4{
# 	font-family: 'Fenix', serif;
#        }
#     h5 {
# ...

# %% [markdown]
# [Back to top](#top)
