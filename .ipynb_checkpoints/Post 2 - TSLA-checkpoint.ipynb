# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import scipy as scp

# %%
import pandas.io.data as web
import datetime

# %%
start_date = datetime.datetime(2009,1,1)
end_date = datetime.datetime.today()
ticker = 'TSLA'
src = 'yahoo'

# %%
underlying = web.DataReader(ticker,src,start_date,end_date)
underlying.Close.plot()

# %%
# options = web.Options(ticker,src).get_all_data()

# %%
usernames = ['elonmusk','TeslaMotors','SpaceX']

# %% [markdown]
# ### Import from Twitter API

# %%
from tweet_dumper import get_all_tweets

# %%
tweets = {}
for user in usernames:
    tweets[user]= pd.DataFrame(get_all_tweets(user),columns=['Id','Date','Tweet'])
df = pd.DataFrame.join(tweets)
# Out:
# getting tweets before 408030622708678656
# ...400 tweets downloaded so far
# getting tweets before 336598500156518399
# ...600 tweets downloaded so far
# getting tweets before 307597163582590976
# ...800 tweets downloaded so far
# getting tweets before 226992186493919231
# ...999 tweets downloaded so far
# getting tweets before 151752772809801727
# ...1024 tweets downloaded so far
# getting tweets before 15434727181
# ...1024 tweets downloaded so far
# getting tweets before 497179394486439935
# ...400 tweets downloaded so far
# getting tweets before 491265017883275263
# ...600 tweets downloaded so far
# getting tweets before 483310945687863295
# ...799 tweets downloaded so far
# getting tweets before 476786395726360575
# ...999 tweets downloaded so far
# getting tweets before 469215716126629887
# ...1199 tweets downloaded so far
# getting tweets before 462255870949085184
# ...1399 tweets downloaded so far
# getting tweets before 456197667463249919
# ...1599 tweets downloaded so far
# ...

# %% [markdown]
# ### Import from previously downloaded data

# %%
fnames = [username+'_tweets.csv' for username in usernames]
#fnames = ['elonmusk_tweets.csv','TeslaMotors_tweets.csv','SpaceX_tweets.csv']
df = pd.concat([pd.read_csv(fname,header=0) for fname in fnames])
df.set_index('created_at',inplace=True)
df.index = pd.to_datetime(df.index)
dfg = df.groupby(df.index.map(lambda x: x.year))

# %%
df2 = underlying.join(df,how='outer')

# %%
dfg = df2.groupby(lambda x: x.date)

# %%
df2['num_tweets'] = df2['text'].groupby(lambda x: x.date).count()

# %%
s_tweets = df2['text']
df2['bin_tweet']= s_tweets.apply(str)
df2['bin_tweet'] = df2['bin_tweet'].apply(lambda x: 0 if x=='nan' else 1)

# %%
df2.resample('D',how='count')
# Out:
#             Open  High  Low  Close  Volume  Adj Close  id  text  num_tweets
# 2009-04-24     0     0    0      0       0          0   1     1           0
# 2009-04-25     0     0    0      0       0          0   0     0           0
# 2009-04-26     0     0    0      0       0          0   0     0           0
# 2009-04-27     0     0    0      0       0          0   0     0           0
# 2009-04-28     0     0    0      0       0          0   0     0           0
# 2009-04-29     0     0    0      0       0          0   1     1           0
# 2009-04-30     0     0    0      0       0          0   2     2           0
# 2009-05-01     0     0    0      0       0          0   0     0           0
# 2009-05-02     0     0    0      0       0          0   0     0           0
# 2009-05-03     0     0    0      0       0          0   0     0           0
# 2009-05-04     0     0    0      0       0          0   0     0           0
# ...

# %%
df2
# Out:
#                        Open    High     Low   Close   Volume  Adj Close  \
# 2009-04-24 17:30:47     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-04-29 16:16:14     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-04-30 14:59:57     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-04-30 15:02:35     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-05-11 16:32:48     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-05-28 13:33:18     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-01 15:32:16     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-01 21:57:11     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-03 21:30:28     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-08 16:32:31     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-16 23:03:35     NaN     NaN     NaN     NaN      NaN        NaN
# 2009-06-24 18:42:03     NaN     NaN     NaN     NaN      NaN        NaN
# ...

# %%
ax=df2['Volume'].plot()
ymin, ymax = ax.get_ylim()
ax.vlines(df2.index, ymin=ymin, ymax=ymax-1, color='r')
